# %% [markdown]
# <a href="https://colab.research.google.com/github/elnashara/Home/blob/master/COVID19Assigment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pulmonary Risks

# %% [markdown]
# ### COVID-19 pulmonary risks literature clustering
# - author = {Gerry Wolfe, Will Schreiber, Ashraf Elnashar}
# - title = {COVID-19 pulmonary risks literature clustering}
# - year = {2020}
# - month = {April}
# - location = {Syracuse University, USA}

# %% [markdown]
# ## Abstract
# COVID-19, short for "coronavirus disease 2019," has majorly affected millions of people around the globe. In the US alone as of the end of this week (April 18, 2020), there have been 690,714 total cases, with 35,443 deaths. In the entire world there have been 2,325,335 cases with 160,448 deaths. And these are just the reported cases.
#
# Our perspective for this project is essentially a bottom up approach searching for ideas, answers, and information in the COVID -19 dataset concentrating on the pulmonary related diseases and their relationship to COVID-19.
# We are using a combination of clustering, classifying, and related datasets to accomplish this. As we delve further into our reseach, we expect to add to this abstract and we expect that our research will lead to modifications in our approach.
# The Dataset we are using is the COVID-19 Open Research Dataset Challenge from Kaggle, and we are focusing on a subset of that, COVID-19 Pulmonary Risks Literature Clustering, also from Kaggle.
#
# [Remainder of abstract to be completed as the project continues]

# %% [markdown]
# # Introduction
#
# COVID-19 is the official name given by the [World Health Organization](https://www.who.int/emergencies/diseases/novel-coronavirus-2019/situation-reports/) to the disease caused by this newly identified coronavirus.
# Coronaviruses are an extremely common cause of colds and other upper respiratory infections.
# The most up-to-date information is available from the [World Health Organization]((https://www.who.int/emergencies/diseases/novel-coronavirus-2019/situation-reports/)), the [US Centers for Disease Control and Prevention](https://www.cdc.gov/coronavirus/2019-ncov/cases-updates/cases-in-us.html?CDC_AA_refVal=https%3A%2F%2Fwww.cdc.gov%2Fcoronavirus%2F2019-ncov%2Fcases-in-us.html), [Johns Hopkins University](https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6), and [Maryland Transportation Institute](https://data.covid.umd.edu/).
#
# It has spread so rapidly and to so many countries that the [World Health Organization](https://www.who.int/emergencies/diseases/novel-coronavirus-2019/situation-reports/) has declared it a pandemic (a term indicating that it has affected a large population, region, country, or continent).

# %% [markdown]
# # Goal & Research Questions
# - Given the large amount of literature and the rapid spread of COVID-19, the the literature has not been able to be effectively organized. This project is meant to help organize the literature related to pulmonary diseases and its effect on COVID-19.
#
# -  We intend on clustering the articles surrounding pulmonary related diseases to help researchers better determine possible trends, opportunities of research, and focus. We will focus on quantifying this data so we can help determine the important factors in the tidal wave of articles.
#
# -  We will also be using the Maryland Transportation Institute dataset related to transportation and social distancing. We are looking at this data because at this time, it seems the data here is highly uncorrelated to pulmonary diseases. This data will help us answer the following question.
#
# -  Are there any trends uncovered in the literature discussing certain risk factors, specifically social distancing from the Maryland Transportation website that have no direct correlation with pulmonary risk factors?
#
# -  We also are interested in determining if the literature discusses the percentages of risk between different types of smoking, such as cigarette, cigar, or marijuana? In other words, is it possible marijuana smokers may have a higher risk than cigarette smokers?

# %% [markdown]
# # Approach:
#
# - Parse the text from the body of each document.
# - Create feature vectors.
# - Applying dimensional reduction to each feature vector.
# - Apply k-means or another clustering algorithm to label the data.
# - Extract the important clusters and analyze the classified data.

# %% [markdown]
# ### Dataset Description - Allen Institute
#
# >In response to the COVID-19 pandemic, the White House and a coalition of leading research groups have prepared the COVID-19 Open Research Dataset (CORD-19). CORD-19 is a resource of over 51,000 scholarly articles, including over 40,000 with full text, about COVID-19, SARS-CoV-2, and related coronaviruses. This freely available dataset is provided to the global research community to apply recent advances in natural language processing and other AI techniques to generate new insights in support of the ongoing fight against this infectious disease. There is a growing urgency for these approaches because of the rapid acceleration in new coronavirus literature, making it difficult for the medical research community to keep up.
# > #### Cite: [COVID-19 Open Research Dataset Challenge (CORD-19) | Kaggle](https://www.kaggle.com/allen-institute-for-ai/CORD-19-research-challenge)
# > #### Kaggle Submission: [COVID-19 Pulmonary Risks Literature Clustering | Kaggle](https://www.kaggle.com/crywolfe/pulmonaryrisks)
#
# ### Dataset Description - Maryland Transportation
#
# > Researchers at the University of Maryland (UMD) are exploring how social distancing and stay-at-home orders are affecting travel behavior and spread of the coronavirus. With privacy-protected data from mobile devices, government agencies, health care systems, and other sources, we are also studying the multifaceted impact of COVID-19 on our mobility, health, economy, and society. Through this interactive analytics platform, we are making our data and research findings available to other researchers, agencies, non-profits, media, and the general public. The platform will evolve and expand over time as new data and impact metrics are computed and additional visualizations are developed.
#
# > #### Cite: [COVID-19 Impact Analysis Platform](https://data.covid.umd.edu/)

# %% [markdown]
# # Loading Data

# %% [markdown]
# ## Loading Dataset

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-64311cfb-eeaa-49d9-87ac-670acbeae6e2" name="files[]" multiple disabled />
#      <output id="result-64311cfb-eeaa-49d9-87ac-670acbeae6e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"ashrafelnashar","key":"775a224b5174bcbf70af20375cf1f61c"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list

# %%
# !kaggle datasets download -d allen-institute-for-ai/CORD-19-research-challenge
# Out:
# Downloading CORD-19-research-challenge.zip to /content
# 100% 2.75G/2.75G [00:42<00:00, 37.7MB/s]
# 100% 2.75G/2.75G [00:42<00:00, 69.1MB/s]

# %%
# !pwd
# !cd content/
# !mkdir CORD-19
# Out:
# /content
# /bin/bash: line 0: cd: content/: No such file or directory

# %%
# !unzip CORD-19-research-challenge.zip  -d /content/CORD-19/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176212.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176213.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176214.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176215.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176216.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176217.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176218.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176219.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176220.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176221.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176222.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176223.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176224.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176225.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176226.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176227.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176228.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176229.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176230.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176231.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176232.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176234.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176235.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176236.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176237.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176238.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176239.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176240.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176241.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176243.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176245.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176254.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176256.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176257.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176258.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176259.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176260.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176261.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176263.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176264.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176265.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176266.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176267.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176268.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176269.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176270.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176271.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176273.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176293.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176310.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176311.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176313.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176314.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176336.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176372.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176373.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176378.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176380.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176383.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176388.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176389.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176390.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176392.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176394.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176395.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176464.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176465.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176466.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176467.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176468.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176469.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176470.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176471.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176473.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176475.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176476.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176477.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176478.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176490.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176573.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176575.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176580.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176581.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176590.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176631.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176813.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176919.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176926.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176927.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176944.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7176984.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177006.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177015.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177020.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177026.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177027.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177028.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177038.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177040.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177041.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177048.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177049.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177053.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177057.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177059.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177061.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177062.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177063.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177064.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177066.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177068.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177070.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177071.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177072.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177073.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177074.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177075.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177078.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177079.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177080.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177082.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177083.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177084.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177085.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177088.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177090.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177092.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177093.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177095.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177097.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177098.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177100.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177101.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177104.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177105.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177107.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177108.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177109.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177110.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177111.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177112.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177113.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177115.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177116.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177117.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177118.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177119.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177120.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177122.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177124.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177125.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177126.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177127.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177130.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177133.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177134.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177138.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177139.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177140.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177144.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177146.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177147.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177149.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177151.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177169.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177179.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177222.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177341.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177352.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177389.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177466.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177503.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177520.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177594.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177596.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177617.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177660.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177691.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177730.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177756.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177765.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177800.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177809.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177813.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177837.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177854.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7177898.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178019.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178089.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178096.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178098.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178099.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178153.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178210.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178250.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178303.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178358.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178552.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178575.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178614.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178636.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178760.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178815.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178823.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178830.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178832.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178837.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178841.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178843.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178845.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178847.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178848.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178851.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178852.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178853.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178857.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178861.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178863.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178867.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178869.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178870.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178873.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178878.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178885.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178894.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178895.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178901.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178902.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178920.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178921.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178922.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178923.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178924.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178925.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7178926.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179051.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179052.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179053.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179054.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179055.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179056.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179058.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179059.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179060.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179061.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179062.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179063.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179064.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179065.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179066.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179067.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179167.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179239.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179274.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179370.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179371.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179372.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179373.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179376.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179377.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179378.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179379.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179380.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179482.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179483.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179484.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179485.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179486.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179487.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179488.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179490.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179491.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179493.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179494.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179495.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179496.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179500.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179501.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179502.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179503.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179504.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179506.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179507.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179508.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179514.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179515.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179517.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179518.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179519.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179520.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179521.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179522.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179523.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179524.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179525.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179526.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179527.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179528.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179529.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179530.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179531.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179532.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179533.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179534.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179535.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179536.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179537.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179538.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179539.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179540.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179541.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179542.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179543.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179544.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179545.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179546.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179547.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179548.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179549.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179550.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179551.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179553.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179554.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179555.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179556.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179557.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179558.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179559.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179560.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179561.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179562.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179563.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179581.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179632.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179703.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179718.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179739.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179740.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179770.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179791.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179792.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179794.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179795.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179796.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179801.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179937.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179953.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179960.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179962.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179963.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179965.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179966.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179980.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179981.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179986.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179991.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179993.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7179995.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180007.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180008.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180011.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180012.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180013.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180014.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180015.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180017.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180019.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180020.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180025.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180027.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180031.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180033.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180034.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180038.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180041.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180043.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180045.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180154.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180156.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180157.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180158.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180159.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180189.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180238.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180242.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180250.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180262.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180324.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180326.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180327.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180328.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180329.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180330.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180332.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180343.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180347.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180348.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180349.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180351.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180355.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180358.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180359.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180360.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180365.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180366.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180367.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180368.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180372.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180373.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180374.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180375.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180376.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180377.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180378.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180379.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180381.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180382.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180383.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180422.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180448.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180491.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180634.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180636.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180637.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180640.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180644.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180646.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180647.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180648.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180649.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180651.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180652.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180653.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180655.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180657.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180658.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180666.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180670.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180672.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180673.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180674.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180676.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180677.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180678.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180680.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180681.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180682.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180683.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180684.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180803.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7180963.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181063.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181098.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181099.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181102.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181104.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181105.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181107.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181108.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181109.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181110.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181112.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181214.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181215.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181396.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181399.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181400.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181401.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181448.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181453.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181509.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181533.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181612.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181865.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181905.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181913.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181916.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181920.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181935.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181939.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181962.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181963.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181970.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181977.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181981.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181991.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181992.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181995.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181997.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7181998.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182015.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182016.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182017.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182018.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182030.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182052.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182092.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182093.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182105.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182108.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182109.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182111.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182112.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182113.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182114.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182116.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182141.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182165.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182166.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182198.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182231.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182252.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182255.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182267.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182282.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182289.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182298.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182299.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182300.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182301.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182304.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182305.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182309.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182341.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182344.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182392.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182393.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182394.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182505.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182506.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182507.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182509.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182512.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182513.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182515.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182516.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182517.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182518.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182519.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182520.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182521.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182522.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182523.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182524.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182525.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182526.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182527.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182529.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182530.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182532.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182604.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182640.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182641.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182642.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182643.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182644.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182645.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182683.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182684.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182697.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182734.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182736.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182740.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182741.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182742.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182743.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182745.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182748.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182749.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182750.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182751.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182752.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182753.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182754.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182755.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182757.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7182770.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183105.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183199.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183244.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183245.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183246.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183247.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183249.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183253.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183254.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183255.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183256.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183257.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183287.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183288.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183294.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183387.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183388.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183389.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183390.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183391.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183392.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183450.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183451.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183472.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183480.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183548.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183610.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183660.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183698.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183724.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183742.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183743.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183744.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183809.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183816.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183817.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183818.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183819.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183823.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183828.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183829.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183833.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183834.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183836.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7183837.xml.json
# ...
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220538.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220539.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220558.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220561.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220563.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220565.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220566.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220567.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220569.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220570.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220573.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220574.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220575.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220577.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220578.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220579.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220580.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220585.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220586.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220587.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220588.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220589.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220590.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220591.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220593.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220595.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220596.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220599.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220603.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220604.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220605.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220607.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220608.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220610.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220611.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220613.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220614.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220615.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220616.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220617.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220618.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220621.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220622.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220623.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220627.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220628.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220639.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220640.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220641.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220642.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220643.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220644.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220645.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220646.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220647.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220648.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220649.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220650.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220651.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220654.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220806.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220807.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220809.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220846.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220848.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220849.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220850.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7220865.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221002.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221005.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221011.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221225.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221228.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221231.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221233.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221234.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221236.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221239.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221289.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221326.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221328.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221329.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221330.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221331.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221334.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221337.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221338.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221339.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221361.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221363.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221366.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221367.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221369.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221370.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221372.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221373.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221374.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221375.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221377.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221378.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221379.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221380.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221385.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221389.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221390.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221393.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221403.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221405.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221406.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221407.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221408.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221409.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7221577.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222038.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222039.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222041.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222043.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222044.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222045.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222048.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222050.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222052.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222053.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222054.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222055.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222056.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222057.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222060.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222061.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222063.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222064.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222066.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222067.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222069.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222071.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222075.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222077.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222079.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222081.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222082.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222085.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222087.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222091.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222093.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222097.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222101.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222104.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222106.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222107.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222109.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222110.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222111.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222112.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222114.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222121.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222122.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222125.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222126.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222127.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222128.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222129.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222130.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222131.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222132.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222133.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222136.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222138.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222139.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222140.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222144.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222146.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222149.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222150.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222151.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222152.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222153.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222154.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222158.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222160.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222161.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222162.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222163.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222165.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222166.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222167.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222169.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222171.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222222.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222512.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222528.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222530.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222542.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222554.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222575.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222576.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222577.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222578.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222613.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222627.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7222643.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7224340.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7224604.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7224605.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7224608.xml.json
#   inflating: /content/CORD-19/document_parses/pmc_json/PMC7224609.xml.json
#   inflating: /content/CORD-19/json_schema.txt
#   inflating: /content/CORD-19/metadata.csv
#   inflating: /content/CORD-19/metadata.readme

# %%
# !ls /content/CORD-19
# Out:
# cord_19_embeddings	 document_parses  Kaggle	metadata.readme
# COVID.DATA.LIC.AGMT.pdf  json_schema.txt  metadata.csv

# %% [markdown]
# ## Installing and Importing Libraries

# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install scispacy
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2020.4.5.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (4.6.3)
# Collecting scispacy
#   Downloading https://files.pythonhosted.org/packages/eb/50/95cd574c3ccf4a268b334ea3c4c3cf9f95d1f24d6c0be82024d51c3e460b/scispacy-0.2.4.tar.gz
# Requirement already satisfied: spacy>=2.2.1 in /usr/local/lib/python3.6/dist-packages (from scispacy) (2.2.4)
# Collecting awscli
#   Downloading https://files.pythonhosted.org/packages/22/64/e5e2a1c8c277c99377e34943d802a389637a102cd3923bd6608b5ec220ea/awscli-1.18.66-py2.py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 12.0MB/s
# Collecting conllu
#   Downloading https://files.pythonhosted.org/packages/a8/03/4a952eb39cdc8da80a6a2416252e71784dda6bf9d726ab98065fff2aeb73/conllu-2.3.2-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from scispacy) (1.18.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from scispacy) (0.15.1)
# Collecting nmslib>=1.7.3.6
#   Downloading https://files.pythonhosted.org/packages/d5/fd/7d7428d29f12be5d1cc6d586d425b795cc9c596ae669593fd4f388602010/nmslib-2.0.6-cp36-cp36m-manylinux2010_x86_64.whl (12.9MB)
#      |████████████████████████████████| 13.0MB 252kB/s
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.6/dist-packages (from scispacy) (0.22.2.post1)
# Collecting pysbd
#   Downloading https://files.pythonhosted.org/packages/3b/49/4799b3cdf80aee5fa4562a3929eda738845900bbeef4ee60481196ad4d1a/pysbd-0.2.3-py3-none-any.whl
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (7.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (4.41.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (0.6.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (2.0.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (3.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (46.3.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.1->scispacy) (1.0.2)
# Collecting colorama<0.4.4,>=0.2.5; python_version != "3.4"
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from awscli->scispacy) (0.3.3)
# Collecting rsa<=3.5.0,>=3.1.2
#   Downloading https://files.pythonhosted.org/packages/e1/ae/baedc9cb175552e95f3395c43055a6a5e125ae4d48a1d7a924baca83e92e/rsa-3.4.2-py2.py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 8.9MB/s
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from awscli->scispacy) (0.15.2)
# Collecting botocore==1.16.16
#   Downloading https://files.pythonhosted.org/packages/17/ac/b21f4aba98f239ee5341d79c64bb502a64ad8ac98331bf0d9568707c6576/botocore-1.16.16-py2.py3-none-any.whl (6.2MB)
#      |████████████████████████████████| 6.2MB 43.4MB/s
# Requirement already satisfied: PyYAML<5.4,>=3.10; python_version != "3.4" in /usr/local/lib/python3.6/dist-packages (from awscli->scispacy) (3.13)
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (from nmslib>=1.7.3.6->scispacy) (5.4.8)
# Collecting pybind11>=2.2.3
#   Downloading https://files.pythonhosted.org/packages/89/e3/d576f6f02bc75bacbc3d42494e8f1d063c95617d86648dba243c2cb3963e/pybind11-2.5.0-py2.py3-none-any.whl (296kB)
#      |████████████████████████████████| 296kB 59.8MB/s
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20.3->scispacy) (1.4.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->scispacy) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->scispacy) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->scispacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.1->scispacy) (1.24.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.1->scispacy) (1.6.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<=3.5.0,>=3.1.2->awscli->scispacy) (0.4.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore==1.16.16->awscli->scispacy) (2.8.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from botocore==1.16.16->awscli->scispacy) (0.10.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.1->scispacy) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.16.16->awscli->scispacy) (1.12.0)
# Building wheels for collected packages: scispacy
#   Building wheel for scispacy (setup.py) ... done
#   Created wheel for scispacy: filename=scispacy-0.2.4-cp36-none-any.whl size=35204 sha256=8c9f1eceef05ee11f7e151cb58bc3024fc669e9aadf41855d58615b4b421b20c
#   Stored in directory: /root/.cache/pip/wheels/36/5e/7c/ba8d6b02f5cfa40735e40ccffd29852ca19ebca59393afd5f0
# Successfully built scispacy
# Installing collected packages: colorama, rsa, botocore, awscli, conllu, pybind11, nmslib, pysbd, scispacy
#   Found existing installation: rsa 4.0
#     Uninstalling rsa-4.0:
#       Successfully uninstalled rsa-4.0
#   Found existing installation: botocore 1.16.13
#     Uninstalling botocore-1.16.13:
#       Successfully uninstalled botocore-1.16.13
# Successfully installed awscli-1.18.66 botocore-1.16.16 colorama-0.4.3 conllu-2.3.2 nmslib-2.0.6 pybind11-2.5.0 pysbd-0.2.3 rsa-3.4.2 scispacy-0.2.4

# %%
import requests
import seaborn as sn
import bs4
import csv
import tensorflow as tf
import pandas as pd 
import numpy as np
import glob
import json
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#|tf.test.gpu_device_name() # is GPU enabled 
# Looks like pandas does not get accelerated with GPU

# %% [markdown]
# ## Load MetaData
# Provides the schema and information from the metadata csv.

# %%
root_path = '/content/CORD-19/'
metadata_path = f'{root_path}/metadata.csv'
meta_df = pd.read_csv(metadata_path, dtype={
    'pubmed_id': str,
    'Microsoft Academic Paper ID': str, 
    'doi': str
})

meta_df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    cord_uid  ... s2_id
# 0  ug7v899j  ...   NaN
# 1  02tnwd4m  ...   NaN
# 2  ejv2xln0  ...   NaN
# 3  2b73a28n  ...   NaN
# 4  9785vg6d  ...   NaN
#
# [5 rows x 19 columns]

# %%
meta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128492 entries, 0 to 128491
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   cord_uid          128492 non-null  object
#  1   sha               55751 non-null   object
#  2   source_x          128492 non-null  object
#  3   title             128464 non-null  object
#  4   doi               100586 non-null  object
#  5   pmcid             60771 non-null   object
#  6   pubmed_id         99124 non-null   object
#  7   license           128492 non-null  object
#  8   abstract          101611 non-null  object
#  9   publish_time      128477 non-null  object
#  10  authors           123725 non-null  object
#  11  journal           122195 non-null  object
#  12  mag_id            0 non-null       float64
#  13  who_covidence_id  17071 non-null   object
#  14  arxiv_id          1395 non-null    object
#  15  pdf_json_files    55751 non-null   object
#  16  pmc_json_files    43753 non-null   object
#  17  url               49173 non-null   object
#  18  s2_id             102980 non-null  float64
# dtypes: float64(2), object(17)
# memory usage: 18.6+ MB

# %% [markdown]
# ## Load JSON

# %%
all_json = glob.glob(f'{root_path}/**/*.json', recursive=True)
len(all_json)
# Out:
# 103314

# %% [markdown]
# ## Helper Function
# This class reads the file and converts to an instance of the filereader class.

# %%
class FileReader:
    def __init__(self, file_path):
        with open(file_path) as file:
            content = json.load(file)
            self.paper_id = content['paper_id']
            self.abstract = []
            self.body_text = []
            # Abstract
            for entry in content['abstract']:
                self.abstract.append(entry['text'])
            # Body text
            for entry in content['body_text']:
                self.body_text.append(entry['text'])
            self.abstract = '\n'.join(self.abstract)
            self.body_text = '\n'.join(self.body_text)
    def __repr__(self):
        return f'{self.paper_id}: {self.abstract[:200]}... {self.body_text[:200]}...'
# first_row = FileReader(all_json[0])
# first_row

# %%
def get_breaks(content, length):
    data = ""
    words = content.split(' ')
    total_chars = 0

    # add break every length characters
    for i in range(len(words)):
        total_chars += len(words[i])
        if total_chars > length:
            data = data + "<br>" + words[i]
            total_chars = 0
        else:
            data = data + " " + words[i]
    return data

# %%
# FileReader(all_json[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-6284130168f1> in <module>()
# ----> 1 FileReader(all_json[1])
#
# <ipython-input-14-6104be89f849> in __init__(self, file_path)
#       7             self.body_text = []
#       8             # Abstract
# ----> 9             for entry in content['abstract']:
#      10                 self.abstract.append(entry['text'])
#      11             # Body text
#
# KeyError: 'abstract'

# %% [markdown]
# ## Build DataFrame from JSON

# %%
dict_ = {'paper_id': [], 'doi':[], 'abstract': [], 'body_text': [], 'authors': [], 'title': [], 'journal': [], 'abstract_summary': []}
for idx, entry in enumerate(all_json):
    if idx > 10:
      break
    # if idx % (len(all_json) // 10) == 0:
    #     print(f'Processing index: {idx} of {len(all_json)}')
    
    try:
        content = FileReader(entry)
    except Exception as e:
        continue  # invalid paper format, skip
    
    # get metadata information
    meta_data = meta_df.loc[meta_df['sha'] == content.paper_id]
    # no metadata, skip this paper
    if len(meta_data) == 0:
        continue
    
    dict_['abstract'].append(content.abstract)
    dict_['paper_id'].append(content.paper_id)
    dict_['body_text'].append(content.body_text)
    
    # also create a column for the summary of abstract to be used in a plot
    if len(content.abstract) == 0: 
        # no abstract provided
        dict_['abstract_summary'].append("Not provided.")
    elif len(content.abstract.split(' ')) > 100:
        # abstract provided is too long for plot, take first 100 words append with ...
        info = content.abstract.split(' ')[:100]
        summary = get_breaks(' '.join(info), 40)
        dict_['abstract_summary'].append(summary + "...")
    else:
        # abstract is short enough
        summary = get_breaks(content.abstract, 40)
        dict_['abstract_summary'].append(summary)
        
    # get metadata information
    meta_data = meta_df.loc[meta_df['sha'] == content.paper_id]
    
    try:
        # if more than one author
        authors = meta_data['authors'].values[0].split(';')
        if len(authors) > 2:
            # if more than 2 authors, take them all with html tag breaks in between
            dict_['authors'].append(get_breaks('. '.join(authors), 40))
        else:
            # authors will fit in plot
            dict_['authors'].append(". ".join(authors))
    except Exception as e:
        # if only one author - or Null valie
        dict_['authors'].append(meta_data['authors'].values[0])
    
    # add the title information, add breaks when needed
    try:
        title = get_breaks(meta_data['title'].values[0], 40)
        dict_['title'].append(title)
    # if title was not provided
    except Exception as e:
        dict_['title'].append(meta_data['title'].values[0])
    
    # add the journal information
    dict_['journal'].append(meta_data['journal'].values[0])
    
    # add doi
    dict_['doi'].append(meta_data['doi'].values[0])
    
df_covid = pd.DataFrame(dict_, columns=['paper_id', 'doi', 'abstract', 'body_text', 'authors', 'title', 'journal', 'abstract_summary'])
df_covid.head()
# Out:
# Empty DataFrame
# Columns: [paper_id, doi, abstract, body_text, authors, title, journal, abstract_summary]
# Index: []

# %% [markdown]
# ### Feature Engineering
# Adding word count columns for both abstract and body_text can be useful parameters later.

# %%
df_covid['abstract_word_count'] = df_covid['abstract'].apply(lambda x: len(x.strip().split()))  # word count in abstract
df_covid['body_word_count'] = df_covid['body_text'].apply(lambda x: len(x.strip().split()))  # word count in body
df_covid['body_unique_words']=df_covid['body_text'].apply(lambda x:len(set(str(x).split())))  # number of unique words in body
df_covid.head()

# %%
df_covid.info()

# %%
df_covid['abstract'].describe(include='all')

# %%
df_covid['body_text'].describe(include='all')

# %% [markdown]
# ### Handle Duplicates

# %%
df_covid.drop_duplicates(['abstract', 'body_text'], inplace=True)
df_covid['abstract'].describe(include='all')

# %%
df_covid['body_text'].describe(include='all')

# %%
df_covid.head()

# %%
df_covid.describe()

# %% [markdown]
# ## Data Pre-Processing
# load sample data (10,000)

# %%
# TODO DELETE we will limit the dataframe to 9 instances
# df = df_covid.sample(9, random_state=42)
# del df_covid
df_covid.head()

# %% [markdown]
# ### Data Clean-Up
#
# we need to clean-up the data to improve any clustering or classification efforts.

# %%
# drop NULL value
df.dropna(inplace=True)
df.info()

# %% [markdown]
# ### Languages
# we need to determine the language of each paper in the dataframe.

# %%
# !pip install langdetect

# %%
from tqdm import tqdm
from langdetect import detect, DetectorFactory

# set seed
DetectorFactory.seed = 0

# hold label - language
languages = []

# go through each text
for ii in tqdm(range(0,len(df))):
    # split by space into list, take the first x intex, join with space
    text = df.iloc[ii]['body_text'].split(" ")
    
    lang = "en"
    try:
        if len(text) > 50:
            lang = detect(" ".join(text[:50]))
        elif len(text) > 0:
            lang = detect(" ".join(text[:len(text)]))
    # ught... beginning of the document was not in a good format
    except Exception as e:
        all_words = set(text)
        try:
            lang = detect(" ".join(all_words))
        # what!! :( let's see if we can find any text in abstract...
        except Exception as e:
            
            try:
                # let's try to label it through the abstract then
                lang = detect(df.iloc[ii]['abstract_summary'])
            except Exception as e:
                lang = "unknown"
                pass
    
    # get the language    
    languages.append(lang)

# %%
from pprint import pprint

languages_dict = {}
for lang in set(languages):
    languages_dict[lang] = languages.count(lang)
    
print("Total: {}\n".format(len(languages)))
pprint(languages_dict)

# %%
df['language'] = languages
plt.bar(range(len(languages_dict)), list(languages_dict.values()), align='center')
plt.xticks(range(len(languages_dict)), list(languages_dict.keys()))
plt.title("Distribution of Languages in Dataset")
plt.show()

# %% [markdown]
# We will be dropping any language that is not English.

# %%
df = df[df['language'] == 'en'] 
df.info()

# %%
# Download the spacy bio parser

from IPython.utils import io
with io.capture_output() as captured:
    # !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_lg-0.2.4.tar.gz
    # !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_sm-0.2.4.tar.gz

# %%
#NLP 
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
# import en_core_sci_lg  # model downloaded in previous step
import en_core_sci_sm

# %% [markdown]
# Part of the preprocessing will be finding and removing stopwords (common words that will act as noise in the clustering step).

# %%
import string

punctuations = string.punctuation
stopwords = list(STOP_WORDS)
stopwords[:10]

# %% [markdown]
# Now the above stopwords are used in everyday english text. Research papers will often frequently use words that don't actually contribute to the meaning and are not considered everyday stopwords

# %%
custom_stop_words = [
    'doi', 'preprint', 'copyright', 'peer', 'reviewed', 'org', 'https', 'et', 'al', 'author', 'figure', 
    'rights', 'reserved', 'permission', 'used', 'using', 'biorxiv', 'medrxiv', 'license', 'fig', 'fig.', 
    'al.', 'Elsevier', 'PMC', 'CZI', 'www'
]

for w in custom_stop_words:
    if w not in stopwords:
        stopwords.append(w)

# %% [markdown]
# The parser function will convert text to lower case, remove punctuation, and find and remove stopwords.
# This is a model for processing biomedical, scientific or clinical text.

# %%
# Parser
parser = en_core_sci_sm.load(disable=["tagger", "ner"])
parser.max_length = 7000000

def spacy_tokenizer(sentence):
    mytokens = parser(sentence)
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]
    mytokens = [ word for word in mytokens if word not in stopwords and word not in punctuations ]
    mytokens = " ".join([i for i in mytokens])
    return mytokens

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
def vectorize(text, maxx_features):
    
    vectorizer = TfidfVectorizer(max_features=maxx_features)
    X = vectorizer.fit_transform(text)
    return X

# %%
body_text_sample_df = df["body_text"].head(2000)
print(body_text_sample_df)
abstract_sample_df = df['abstract'].head(2000)
print(abstract_sample_df)

# %%
tqdm.pandas()
# df["processed_text"] = df["body_text"].progress_apply(spacy_tokenizer)
df["processed_body_text_sample"] = body_text_sample_df.progress_apply(spacy_tokenizer)
df["processed_abstract_sample"] = abstract_sample_df.progress_apply(spacy_tokenizer)

# %%
# !pip install scispacy

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_sm-0.2.4.tar.gz
import scispacy
import spacy
import en_core_sci_sm

nlp = en_core_web_sm.load()
text = """
Myeloid derived suppressor cells (MDSC) are immature 
myeloid cells with immunosuppressive activity. 
They accumulate in tumor-bearing mice and humans 
with different types of cancer, including hepatocellular 
carcinoma (HCC).
"""
doc = nlp(text)

print(list(doc.sents))

# Examine the entities extracted by the mention detector.
# Note that they don't have types like in SpaCy, and they
# are more general (e.g including verbs) - these are any
# spans which might be an entity in UMLS, a large
# biomedical database.
print(doc.ents)


# We can also visualise dependency parses
# (This renders automatically inside a jupyter notebook!):
from spacy import displacy
displacy.render(next(doc.sents), style='dep', jupyter=True)

# %%
df

# %%
df["processed_body_text_sample"]

# %%
# from spacy.lang.en import English
# nlp = English()
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_sm-0.2.4.tar.gz

# !pip install scispacy
# import scispacy
# import spacy

# nlp = spacy.load("en_core_sci_sm")

processed_body_text = nlp(df["processed_body_text_sample"][7])
print(processed_body_text)

# processed_abstract = nlp('positive-stranded rna rna virus exploit host cell machinery subvert')
# print(processed_abstract)

# %%
# python -m spacy download en_core_web_sm
# nlp2 = spacy.load("en_core_sci_sm")
# df["processed_abstract_sample"][1704]

smoking_synonyms = ['smoking',
                    'smoke',
                    'cigar', # this picks up cigar, cigarette, e-cigarette, etc.
                    'nicotine',
                    'cannabis',
                    'marijuana']

COL = {'token1','token2','similarity'}
# tokenSimilarity = pd.DataFrame(columns=COL)

# processed_body_text

smoking_synonyms_tokens = nlp(' '.join(smoking_synonyms))

d = []

for token1 in smoking_synonyms_tokens:
    for token2 in processed_body_text:
      if token1 != token2:
        similarity = token1.similarity(token2)

        if (similarity is not None and similarity > 0.5  and similarity < 1):
          d.append(
            {'token1': token1.text, 'token2': token2.text, 'similarity': similarity})

# smoking_synonyms_tokens_df = pd.DataFrame(d)
# smoking_synonyms_tokens_df

        # tokenSimilarity 
        # tokenSimilarity.append(  token1.text , token2.text , similarity)
        # print(token1.text, token2.text)

# doc = nlp3(text)

# print(list(doc.sents))

# # Examine the entities extracted by the mention detector.
# # Note that they don't have types like in SpaCy, and they
# # are more general (e.g including verbs) - these are any
# # spans which might be an entity in UMLS, a large
# # biomedical database.
# print(doc.ents)


# # We can also visualise dependency parses
# # (This renders automatically inside a jupyter notebook!):
# from spacy import displacy
# displacy.render(next(doc.sents), style='dep', jupyter=True)

# %%
token_df = pd.DataFrame(d)
token_df

# %%
token_df.similarity

# %%
token_df['similarity_max'] = token_df.groupby(['token1'])['similarity'].transform(max)

# %%
index = token_df.groupby(['token1'])['similarity'].transform(max) == token_df['similarity']
token_df[index]

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.2.4/en_core_sci_sm-0.2.4.tar.gz
import en_core_sci_sm
nlp = en_core_web_sm.load()
text = """
Myeloid derived suppressor cells (MDSC) are immature 
myeloid cells with immunosuppressive activity. 
They accumulate in tumor-bearing mice and humans 
with different types of cancer, including hepatocellular 
carcinoma (HCC).
"""
doc = nlp(text)

print(list(doc.sents))

# Examine the entities extracted by the mention detector.
# Note that they don't have types like in SpaCy, and they
# are more general (e.g including verbs) - these are any
# spans which might be an entity in UMLS, a large
# biomedical database.
print(doc.ents)


# We can also visualise dependency parses
# (This renders automatically inside a jupyter notebook!):
from spacy import displacy
displacy.render(next(doc.sents), style='dep', jupyter=True, options={'compact':True})

# %%
body_text_sample = body_text_sample_df.values
abstract_sample = abstract_sample_df.values
X1 = vectorize(body_text_sample, 2 ** 12)
X2 = vectorize(abstract_sample, 2 ** 12)
print(X1[0])
print(X2[0])

# %%
from sklearn.decomposition import PCA

pca = PCA(.90)
X1_reduced= pca.fit_transform(X1.toarray())
print(X1_reduced.shape)
X2_reduced= pca.fit_transform(X2.toarray())
print(X2_reduced.shape)

# %%
from sklearn import metrics
from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans

# run kmeans with many different k
distortions_X1 = []
K = range(2, len(X1_reduced[0]-1))
for k in K:
  k_means = KMeans(n_clusters=k, random_state=42).fit(X1_reduced)
  k_means.fit(X1_reduced)
  distortions_X1.append(sum(np.min(cdist(X1_reduced, k_means.cluster_centers_, 'cosine'), axis=1)) / X1.shape[0])
  # print('Found distortion for {} clusters'.format(k))
print(len(distortions_X1))
print(K[-1])

# %%
distortions_X2 = []
K = range(2, len(X2_reduced[0]-1))
for k in K:
    k_means = KMeans(n_clusters=k, random_state=42).fit(X2_reduced)
    k_means.fit(X2_reduced)
    distortions_X2.append(sum(np.min(cdist(X2_reduced, k_means.cluster_centers_, 'cosine'), axis=1)) / X2.shape[0])
    # print('Found distortion for {} clusters'.format(k))
len(K)

# %%
# X_line = [K[0], K[-1]]
# Y_line = [distortions_X1[0], distortions_X1[-1]]

# # Plot the elbow
# plt.plot(K, distortions_X1, 'b-')
# plt.plot(X_line, Y_line, 'r')
# plt.xlabel('k')
# plt.ylabel('Distortion')
# plt.title('The Elbow Method showing the optimal k BODY TEXT')
# plt.show()

# %%
X_line = [K[0], K[-1]]
Y_line = [distortions_X2[0], distortions_X2[-1]]

# Plot the elbow
plt.plot(K, distortions_X2, 'b-')
plt.plot(X_line, Y_line, 'r')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k - ABSTRACT')
plt.show()

# %%
from sklearn.manifold import TSNE

tsne = TSNE(verbose=1, perplexity=100, random_state=42)
X1_embedded = tsne.fit_transform(X1.toarray())
X2_embedded = tsne.fit_transform(X2.toarray())

# %%
k1 = 7
kmeans = KMeans(n_clusters=k1, random_state=42)
y1_pred = kmeans.fit_predict(X1_reduced)
y1_pred.shape

# %%
y1_df = pd.DataFrame(y1_pred)
y1_df

# %%
k2 = 7
kmeans = KMeans(n_clusters=k2, random_state=42)
y2_pred = kmeans.fit_predict(X2_reduced)
df['y2'] = y2_pred

# %%
# sns settings
sn.set(rc={'figure.figsize':(13,13)})

# colors
palette = sn.color_palette("bright", k1)

# plot
sn.scatterplot(X1_embedded[:,0], X1_embedded[:,1], hue=y1_pred, palette=palette)
plt.title('t-SNE with no Labels - BODY')
plt.savefig("t-sne_covid19.png")
plt.show()

# %%
# sns settings
sn.set(rc={'figure.figsize':(13,13)})

# colors
palette = sn.color_palette("bright", k2)

# plot
sn.scatterplot(X2_embedded[:,0], X2_embedded[:,1], hue=y2_pred, palette=palette)
plt.title('t-SNE with no Labels - ABSTRACT')
plt.savefig("t-sne_covid19.png")
plt.show()

# %%
# %matplotlib inline

# sns settings
sn.set(rc={'figure.figsize':(13,13)})

# colors
palette = sn.hls_palette(k1, l=.4, s=.9)

# plot
sn.scatterplot(X1_embedded[:,0], X1_embedded[:,1], hue=y1_pred, legend='full', palette=palette)
plt.title('t-SNE with Kmeans Labels - BODY')
plt.savefig("improved_cluster_tsne.png")
plt.show()

# %%
# %matplotlib inline

# sns settings
sn.set(rc={'figure.figsize':(13,13)})

# colors
palette = sn.hls_palette(k2, l=.4, s=.9)

# plot
sn.scatterplot(X2_embedded[:,0], X2_embedded[:,1], hue=y2_pred, legend='full', palette=palette)
plt.title('t-SNE with Kmeans Labels - ABSTRACT')
plt.savefig("improved_cluster_tsne.png")
plt.show()

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizers = []
    
for ii in range(0, 20):
    # Creating a vectorizer
    vectorizers.append(CountVectorizer(min_df=5, max_df=0.9, stop_words='english', lowercase=True, token_pattern='[a-zA-Z\-][a-zA-Z\-]{2,}'))
vectorizers[0]

# %%
vectorizer1_sample = CountVectorizer()
vectorizer2_sample = CountVectorizer()
print(body_text_sample)
print(abstract_sample)
X1_test = vectorizer1_sample.fit_transform(body_text_sample)
X2_test = vectorizer2_sample.fit_transform(abstract_sample)
print(vectorizer1_sample.get_feature_names())
print(vectorizer2_sample.get_feature_names())

# %%
# df["processed_body_text_sample"][41488]
df["processed_body_text_sample"]

# processed_body_text = nlp(df["processed_body_text_sample"][44048])
# print(processed_body_text)

# processed_abstract = nlp(df["processed_abstract_sample"])
# print(processed_abstract)

# %%
vectorized_data = []

for current_cluster, cvec in enumerate(vectorizers):
    try:
        vectorized_data.append(cvec.fit_transform(df.loc[y1_df == current_cluster, 'processed_text']))
    except Exception as e:
        print("Not enough instances in cluster: " + str(current_cluster))
        vectorized_data.append(None)

# %% [markdown]
# Applying the text-processing function on the body_text.

# %% [markdown]
# Let's take a look at word count in the papers

# %%
sn.distplot(df['body_word_count'])
df['body_word_count'].describe()

# %%
sn.distplot(df['body_unique_words'])
df['body_unique_words'].describe()

# %% [markdown]
# # COVID-19 Analysis

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
# set the dataframe
df = meta_df

def doi_url(d):
    if d.startswith('http'):
        return d
    elif d.startswith('doi.org'):
        return f'http://{d}'
    else:
        return f'http://doi.org/{d}'
    
df.doi = df.doi.fillna('').apply(doi_url)

print(f'loaded DataFrame with {len(df)} records')

# %%
# Helper function for filtering df on abstract + title substring
def abstract_title_filter(search_string):
    return (df.abstract.str.lower().str.replace('-', ' ').str.contains(search_string, na=False) |
            df.title.str.lower().str.replace('-', ' ').str.contains(search_string, na=False))

# %%
# Helper function for Cleveland dot plot visualisation of count data
def dotplot(input_series, title, x_label='Count', y_label='Regex'):
    subtitle = '<br><i>Hover over dots for exact values</i>'
    fig = go.Figure()
    fig.add_trace(go.Scatter(
    x=input_series.sort_values(),
    y=input_series.sort_values().index.values,
    marker=dict(color="crimson", size=12),
    mode="markers",
    name="Count",
    ))
    fig.update_layout(title=f'{title}{subtitle}',
                  xaxis_title=x_label,
                  yaxis_title=y_label)
    fig.show()

# %%
# Helper function which counts synonyms and adds tag column to DF
def count_and_tag(df: pd.DataFrame,
                  synonym_list: list,
                  tag_suffix: str) -> (pd.DataFrame, pd.Series):
    counts = {}
    df[f'tag_{tag_suffix}'] = False
    for s in synonym_list:
        synonym_filter = abstract_title_filter(s)
        counts[s] = sum(synonym_filter)
        df.loc[synonym_filter, f'tag_{tag_suffix}'] = True
    return df, pd.Series(counts)

# %%
# Function for printing out key passage of abstract based on key terms
def print_key_phrases(df, key_terms, n=5, chars=300):
    for ind, item in enumerate(df[:n].itertuples()):
        print(f'{ind+1} of {len(df)}')
        print(item.title)
        print('[ ' + item.doi + ' ]')
        try:
            i = len(item.abstract)
            for kt in key_terms:
                kt = kt.replace(r'\b', '')
                term_loc = item.abstract.lower().find(kt)
                if term_loc != -1:
                    i = min(i, term_loc)
            if i < len(item.abstract):
                print('    "' + item.abstract[i-30:i+chars-30] + '"')
            else:
                print('    "' + item.abstract[:chars] + '"')
        except:
            print('NO ABSTRACT')
        print('---')

# %% [markdown]
# # Diseases
#
# - Covid-19

# %%
covid19_synonyms = ['covid',
                    'coronavirus disease 19',
                    'sars cov 2', # Note that search function replaces '-' with ' '
                    '2019 ncov',
                    '2019ncov',
                    r'2019 n cov\b',
                    r'2019n cov\b',
                    'ncov 2019',
                    r'\bn cov 2019',
                    'coronavirus 2019',
                    'wuhan pneumonia',
                    'wuhan virus',
                    'wuhan coronavirus',
                    r'coronavirus 2\b']

# %%
df, covid19_counts = count_and_tag(df, covid19_synonyms, 'disease_covid19')

# %%
covid19_counts.sort_values(ascending=False)

# %%
dotplot(covid19_counts, 'Covid-19 synonyms in title / abstract metadata')

# %%
novel_corona_filter = (abstract_title_filter('novel corona') &
                       df.publish_time.str.startswith('2020', na=False))
print(f'novel corona (published 2020): {sum(novel_corona_filter)}')
df.loc[novel_corona_filter, 'tag_disease_covid19'] = True

# %%
df.tag_disease_covid19.value_counts()

# %%
# SENSE CHECK: Confirm these all published 2020 (or missing date)
df[df.tag_disease_covid19].publish_time.str.slice(0, 4).value_counts(dropna=False)

# %% [markdown]
# ## Risks¶
#
# Potential risk factors:
# - Generic risk factors
# - Demographic:
#   - Age
#   - Sex
#   - Bodyweight
#   - Blood type
# - Behavioural:
#   - Smoking

# %% [markdown]
# ## Generic risk factors
#
# Look for text that indicates that risk factors are assessed in the paper.

# %%
risk_factor_synonyms = ['risk factor',
                        'risk model',
                        'risk by',
                        'comorbidity',
                        'comorbidities',
                        'coexisting condition',
                        'co existing condition',
                        'clinical characteristics',
                        'clinical features',
                        'demographic characteristics',
                        'demographic features',
                        'behavioural characteristics',
                        'behavioural features',
                        'behavioral characteristics',
                        'behavioral features',
                        'predictive model',
                        'prediction model',
                        'univariate', # implies analysis of risk factors
                        'multivariate', # implies analysis of risk factors
                        'multivariable',
                        'univariable',
                        'odds ratio', # typically mentioned in model report
                        'confidence interval', # typically mentioned in model report
                        'logistic regression',
                        'regression model',
                        'factors predict',
                        'factors which predict',
                        'factors that predict',
                        'factors associated with',
                        'underlying disease',
                        'underlying condition']
df, risk_generic_counts = count_and_tag(df, risk_factor_synonyms, 'risk_generic')
dotplot(risk_generic_counts,
        'Count of generic risk factor indicated in title / abstract')

# %%
risk_generic_counts.sort_values(ascending=False)

# %%
n = (df.tag_disease_covid19 & df.tag_risk_generic).sum()
print(f'There are {n} papers on Covid-19 and generic risk factors.')

# %% [markdown]
# Printing out 5 examples, and key text from the Abstract.

# %%
print_key_phrases(df[df.tag_disease_covid19 & df.tag_risk_generic],
                  risk_factor_synonyms)

# %% [markdown]
# ## Demographic risk factors
#
# ## Age

# %%
age_synonyms = ['median age',
                'mean age',
                'average age',
                'elderly',
                r'\baged\b',
                r'\bold',
                'young',
                'teenager',
                'adult',
                'child'
               ]
df, age_counts = count_and_tag(df, age_synonyms, 'risk_age')
dotplot(age_counts, 'Age synonyms in title / abstract metadata')

# %%
age_counts.sort_values(ascending=False)

# %%
n = (df.tag_disease_covid19 & df.tag_risk_age).sum()
print(f'There are {n} papers on Covid-19 and age.')

# %% [markdown]
# ## Sex
#
# e.g. _Sex difference and smoking predisposition in patients with COVID-19_, https://doi.org/10.1016/S2213-2600(20)30117-X

# %%
sex_synonyms = ['sex',
                'gender',
                r'\bmale\b',
                r'\bfemale\b',
                r'\bmales\b',
                r'\bfemales\b',
                r'\bmen\b',
                r'\bwomen\b'
               ]
df, sex_counts = count_and_tag(df, sex_synonyms, 'risk_sex')
dotplot(sex_counts, 'Sex / gender synonyms in title / abstract metadata')

# %%
sex_counts.sort_values(ascending=False)

# %%
n = (df.tag_disease_covid19 & df.tag_risk_sex).sum()
print(f'There are {n} papers on Covid-19 and sex / gender.')

# %% [markdown]
# ## Bodyweight
#
# Obesity and related problems (e.g. diabetes, hypertension) have been widely speculated as risk factors, e.g. _The confluence of the COVID19 pandemic with the obesity epidemic_, https://doi.org/10.1136/bmj.m810

# %%
bodyweight_synonyms = [
    'overweight',
    'over weight',
    'obese',
    'obesity',
    'bodyweight',
    'body weight',
    r'\bbmi\b',
    'body mass',
    'body fat',
    'bodyfat',
    'kilograms',
    r'\bkg\b', # e.g. 70 kg
    r'\dkg\b'  # e.g. 70kg
]
df, bodyweight_counts = count_and_tag(df, bodyweight_synonyms, 'risk_bodyweight')
dotplot(bodyweight_counts, 'Bodyweight synonyms in title / abstract data')

# %%
bodyweight_counts.sort_values(ascending=False)

# %%
n = (df.tag_disease_covid19 & df.tag_risk_bodyweight).sum()
print(f'There are {n} papers on Covid-19 and bodyweight')

# %%
print_key_phrases(df[df.tag_disease_covid19 & df.tag_risk_bodyweight],
                  bodyweight_synonyms)

# %% [markdown]
# ## Smoking
#
# e.g. _Sex difference and smoking predisposition in patients with COVID-19_,  https://doi.org/10.1016/S2213-2600(20)30117-X
#
# - smoking
# - smoke(rs)
# - cigarette(s)
# - cigar(s)
# - e-cigarette(s)
# - cannabis / marijuana / thc

# %%
smoking_synonyms = ['smoking',
                    'smoke',
                    'cigar', # this picks up cigar, cigarette, e-cigarette, etc.
                    'nicotine',
                    'cannabis',
                    'marijuana']
df, smoking_counts = count_and_tag(df, smoking_synonyms, 'risk_smoking')
dotplot(smoking_counts, 'Smoking synonym counts in title / abstract metadata')

# %%
smoking_counts.sort_values(ascending=False)

# %%
df.groupby('tag_disease_covid19').tag_risk_smoking.value_counts()

# %%
n = (df.tag_disease_covid19 & df.tag_risk_smoking).sum()
print(f'tag_disease_covid19 x tag_risk_smoking currently returns {n} papers')

# %%
print_key_phrases(df[df.tag_disease_covid19 & df.tag_risk_smoking],
                  smoking_synonyms, n=12)

# %% [markdown]
# ## Diabetes
#
# - Type I Diabetes
# - Type II Diabetes

# %%
diabetes_synonyms = [
    'diabet', # picks up diabetes, diabetic, etc.
    'insulin', # any paper mentioning insulin likely to be relevant
    'blood sugar',
    'blood glucose',
    'ketoacidosis',
    'hyperglycemi', # picks up hyperglycemia and hyperglycemic
]
df, diabetes_counts = count_and_tag(df, diabetes_synonyms, 'risk_diabetes')
dotplot(diabetes_counts, 'Diabetes synonym counts in title / abstract metadata')

# %%
diabetes_counts.sort_values(ascending=False)

# %%
n = (df.tag_disease_covid19 & df.tag_risk_diabetes).sum()
print(f'There are {n} papers on Covid-19 and diabetes')

# %%
print_key_phrases(df[df.tag_disease_covid19 & df.tag_risk_diabetes],
                  diabetes_synonyms, n=49)

# %% [markdown]
# ## Chronic respiratory disease

# %%
chronicresp_synonyms = [
    'chronic respiratory disease',
    'asthma',
    'chronic obstructive pulmonary disease',
    r'\bcopd',
    'chronic bronchitis',
    'emphysema'
]
df, chronicresp_counts = count_and_tag(df, chronicresp_synonyms, 'risk_chronicresp')
dotplot(chronicresp_counts, 'Chronic respiratory disease terms in title / abstract metadata')

# %%
chronicresp_counts.sort_values(ascending=False)

# %%
n = (df.tag_disease_covid19 & df.tag_risk_chronicresp).sum()
print(f'There are {n} papers on Covid-19 and chronic respiratory disease')

# %%
print_key_phrases(df[df.tag_disease_covid19 & df.tag_risk_chronicresp],
                  chronicresp_synonyms, n=15)

# %% [markdown]
# ## Asthma

# %%
# Only really one term for asthma
df, asthma_counts = count_and_tag(df, ['asthma'], 'risk_asthma')
asthma_counts

# %%
n = (df.tag_disease_covid19 & df.tag_risk_asthma).sum()
print(f'There are {n} papers on Covid-19 and asthma')

# %%
print_key_phrases(df[df.tag_disease_covid19 & df.tag_risk_asthma],
                  ['asthma'])

# %% [markdown]
# # Immunity
#
# Looking for terms which indicate factors relating to vaccination and immunity.
#
# ## Generic immunity / vaccination
#
# Papers which mention generic themes relating to immunity / vaccination. (As the research develops, we may extend this section to include specific lines of research relating to immunity / vaccination.

# %%
immunity_synonyms = [
    'immunity',
    r'\bvaccin',
    'innoculat'
]
df, immunity_counts = count_and_tag(df, immunity_synonyms, 'immunity_generic')
immunity_counts

# %%
n = (df.tag_disease_covid19 & df.tag_immunity_generic).sum()
print(f'There are {n} papers on Covid-19 and immunity / vaccines')

# %%
print('Intersection of tag_disease_covid19, tag_risk_generic & tag_immunity_generic')
print('=' * 76)
print_key_phrases(df[df.tag_disease_covid19 &
                     df.tag_risk_generic &
                     df.tag_immunity_generic],
                  risk_factor_synonyms + immunity_synonyms)

# %% [markdown]
# # Crawl and Scrape Data from Maryland Institute

# %%
import requests
import pandas as pd
import bs4
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np

# %%
URL_COUNTIES ="https://data.covid.umd.edu/fips-counties.csv"
response = requests.get(URL_COUNTIES, {}).text
web_page = bs4.BeautifulSoup(response, "lxml")
sub_page = web_page.body.find_all("p")
sub_page = sub_page[0]

# %% [markdown]
# ## Build DataFrame

# %%
sub_string = sub_page.string
df_md_states = pd.DataFrame(data=[x.split(',') for x in sub_string.split('\r\n')],
                            columns=['fips', 'county_name', 'state_abbr',	'state_name',	'long_name',	'sumlev',	'region',	'division',	'state',	'county',	'crosswalk',	'region_name',	'division_name'])
df_md_states = df_md_states[1:]
df_md_states.head()

# %%
df_md_states.info()

# %%
URL_NATIONAL ="https://data.covid.umd.edu/data/National.csv"
response_national = requests.get(URL_NATIONAL, {}).text
web_page_national = bs4.BeautifulSoup(response_national, "lxml")
sub_page_national = web_page_national.body.find_all("p")
sub_page_national = sub_page_national[0]
sub_page_national

# %%
# sub_string_national = sub_page_national.string
# df_md_national = pd.DataFrame(data=[x.split(',') for x in sub_string_national.split('\n')],
                            # columns=['name','social_distancing_index','%_staying_home','#trips/person','%_out-of-county_trips','miles_traveled/person','#work_trips/person','#non-work_trips/person','covid_case_count','population','date'])
# df_md_national = df_md_national[1:]
# df_md_national.head()

# %%
sub_string_national = sub_page_national.string
df_md_national = pd.DataFrame(data=[x.split(',') for x in sub_string_national.split('\n')],
                            columns=['Name',
 'Social_distancing_index',
 '%_staying_home',
 'Trips/person',
 '%_External_trips',
 'Miles/person',
 'Work_trips/person',
 'Non-work_trips/person',
 'New_COVID_cases',
 'Population',
 '%_change_in_consumption',
 'date',
 'Transit_mode_share',
 '%_people_older_than_60',
 'Median_income',
 '%_African_Americans',
 '%_Hispanic_Americans',
 '%_Male',
 'Population_density',
 'Employment_density',
 '#_hot_spots/1000_people',
 'Hospital_beds/1000_people',
 'ICUs/1000_people',
 '%_hospital_bed_utilization',
 '#_contact_tracing_workers/1000_people',
 'COVID_exposure/1000_people',
 '#days:_decreasing_ILI_cases',
 'Unemployment_claims/1000_people',
 'Unemployment_rate',
 '%_working_from_home',
 'Cumulative_inflation_rate',
 'COVID_death_rate',
 'New_cases/1000_people',
 'Active_cases/1000_people',
 '#days:_decreasing_COVID_cases',
 'Testing_capacity',
 'Tests_done/1000_people',
 '%_ICU_utilization',
 'Ventilator_shortage',
 'Imported_COVID_cases'])
df_md_national = df_md_national[1:]
# df_md_national.head()

# %%
# [x.split(',') for x in sub_string_national.split('\n')][0]

# %% [markdown]
# # PRE-PROCESSING

# %%
# !jupyter nbconvert --to html COVID19Assignment.ipynbd
# TODO handle dupl, etc. look at description

# Approach. think about classifiers.
df_md_states['fips'] = df_md_states['fips'].astype(int)
df_md_states['county_name'] = df_md_states['county_name'].astype('string')
df_md_states['state_abbr'] = df_md_states['state_abbr'].astype('string')
df_md_states['state_name'] = df_md_states['state_name'].astype('string')
df_md_states['long_name'] = df_md_states['long_name'].astype('string')
df_md_states = df_md_states[df_md_states['sumlev'] != 'NA']
df_md_states['sumlev'] = df_md_states['sumlev'].astype(int)
df_md_states['region'] = df_md_states['region'].astype(int)
df_md_states['division'] = df_md_states['division'].astype(int)
df_md_states['state'] = df_md_states['state'].astype(int)
df_md_states['county'] = df_md_states['county'].astype(int)
df_md_states['crosswalk'] = df_md_states['crosswalk'].astype('string')
df_md_states['region_name'] = df_md_states['region_name'].astype('string')
df_md_states['division_name'] = df_md_states['division_name'].astype('string')

# %%
df_md_states.info()

# %%
df_md_national.info()

# %%
df_md_national = df_md_national.dropna()
df_md_national

# %%
df_md_national['Name'] = df_md_national['Name'].astype('string')
df_md_national['Social_distancing_index'] = df_md_national['Social_distancing_index'].astype(int)
df_md_national['%_staying_home'] = df_md_national['%_staying_home'].astype(int)
df_md_national['Trips/person'] = df_md_national['Trips/person'].astype('string')
df_md_national['%_External_trips'] = df_md_national['%_External_trips'].astype(float)
df_md_national['Miles/person'] = df_md_national['Miles/person'].astype(float)
df_md_national['Work_trips/person'] = df_md_national['Work_trips/person'].astype(float)
df_md_national['Non-work_trips/person'] = df_md_national['Non-work_trips/person'].astype(float)
df_md_national['New_COVID_cases'] = df_md_national['New_COVID_cases'].astype(int)
df_md_national['Population'] = df_md_national['Population'].astype(int)
df_md_national['%_change_in_consumption'] = df_md_national['%_change_in_consumption'].astype(float)
df_md_national['date'] = df_md_national['date'].astype('string')
df_md_national['Transit_mode_share'] = df_md_national['Transit_mode_share'].astype(float)
df_md_national['%_people_older_than_60'] = df_md_national['%_people_older_than_60'].astype(int)
df_md_national['Median_income'] = df_md_national['Median_income'].astype(int)
df_md_national['%_African_Americans'] = df_md_national['%_African_Americans'].astype(float)
df_md_national['%_Hispanic_Americans'] = df_md_national['%_Hispanic_Americans'].astype(float)
df_md_national['%_Male'] = df_md_national['%_Male'].astype(float)
df_md_national['Population_density'] = df_md_national['Population_density'].astype(int)
df_md_national['Employment_density'] = df_md_national['Employment_density'].astype(int)
df_md_national['#_hot_spots/1000_people'] = df_md_national['#_hot_spots/1000_people'].astype(int)
df_md_national['Hospital_beds/1000_people'] = df_md_national['Hospital_beds/1000_people'].astype(float)
df_md_national['ICUs/1000_people'] = df_md_national['ICUs/1000_people'].astype(float)
df_md_national['%_hospital_bed_utilization'] = df_md_national['%_hospital_bed_utilization'].astype(float)
df_md_national['#_contact_tracing_workers/1000_people'] = df_md_national['#_contact_tracing_workers/1000_people'].astype(float)
df_md_national['COVID_exposure/1000_people'] = df_md_national['COVID_exposure/1000_people'].astype(float)
df_md_national['#days:_decreasing_ILI_cases'] = df_md_national['#days:_decreasing_ILI_cases'].astype(float)
df_md_national['Unemployment_claims/1000_people'] = df_md_national['Unemployment_claims/1000_people'].astype(float)
df_md_national['Unemployment_rate'] = df_md_national['Unemployment_rate'].astype(float)
df_md_national['%_working_from_home'] = df_md_national['%_working_from_home'].astype(float)
df_md_national['Cumulative_inflation_rate'] = df_md_national['Cumulative_inflation_rate'].astype(float)
df_md_national['COVID_death_rate'] = df_md_national['COVID_death_rate'].astype(float)
df_md_national['New_cases/1000_people'] = df_md_national['New_cases/1000_people'].astype(float)
df_md_national['Active_cases/1000_people'] = df_md_national['Active_cases/1000_people'].astype(float)
df_md_national['#days:_decreasing_COVID_cases'] = df_md_national['#days:_decreasing_COVID_cases'].astype(int)
df_md_national['Testing_capacity'] = df_md_national['Testing_capacity'].astype(float)
df_md_national['Tests_done/1000_people'] = df_md_national['Tests_done/1000_people'].astype(float)
df_md_national['%_ICU_utilization'] = df_md_national['%_ICU_utilization'].astype(float)
df_md_national['Ventilator_shortage'] = df_md_national['Ventilator_shortage'].astype(int)
df_md_national['Imported_COVID_cases'] = df_md_national['Imported_COVID_cases'].astype(int)

# %%
df_md_national['target'] = pd.cut(df_md_national['New_cases/1000_people'], bins=2, labels=np.arange(2), right=False)
df_md_national['target']

# %%
def meta_data(data):
  total = data.isnull().sum()
  percent = (data.isnull().sum()/data.isnull().count()*100)
  unique = data.nunique()
  datatypes = data.dtypes
  return pd.concat([total, percent, unique, datatypes], axis=1, keys=['Total', 'Percent', 'Unique', 'Data_Type']).sort_values(by="Percent", ascending=False)

# %%
#calculating meta-data for application_data
app_meta_data=meta_data(df_md_national)
app_meta_data = app_meta_data.loc[app_meta_data['Unique'] != 1]
# app_meta_data = app_meta_data.loc[:,app_meta_data.apply(pd.Series.nunique) != 1]
app_meta_data

# %%
cols= ['COVID_exposure/1000_people','#days:_decreasing_ILI_cases','Unemployment_claims/1000_people','Unemployment_rate','%_working_from_home',
       'Cumulative_inflation_rate','COVID_death_rate','Active_cases/1000_people','#days:_decreasing_COVID_cases',
       'Testing_capacity','Tests_done/1000_people','%_ICU_utilization','Ventilator_shortage','Imported_COVID_cases','Social_distancing_index',
       '%_staying_home','Trips/person','%_External_trips','Miles/person','Work_trips/person','Non-work_trips/person','New_COVID_cases',
       '%_change_in_consumption']
# cols_2 = list(app_meta_data.columns)
# cols_2
app_meta_data.index.values.tolist()

# %%
defaulters_1=df_md_national[cols]
defaulters_pearson_corr = defaulters_1.corr(method='pearson')
round(defaulters_pearson_corr, 3)
# dcorr_parson = defaulters_1.corr(method ='pearson')
# dcorr_parson.iloc[1:25, :0]

# %%
# figure size
plt.figure(figsize=(15,10))
# heatmap
sns.heatmap(defaulters_pearson_corr, cmap="YlGnBu", annot=True)
plt.show()

# %%
# Create abs correlation matrix
corr_matrix = defaulters_pearson_corr.abs()
# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
# Find index of feature columns with correlation greater than 0.4
to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]
# Drop features 
meta_app_df_pearson = defaulters_1.drop(defaulters_1[to_drop], axis=1)
meta_app_df_pearson

# %%
# df_md_national.min()['New_cases/1000_people']

# %%
# cols=['Social_distancing_index', '%_staying_home', 'Trips/person', '%_External_trips']
# cols_target=['New_cases/1000_people']
X = df_md_national[list(meta_app_df_pearson.columns)]

y = df_md_national.target

# %%
pearson_cols = list(meta_app_df_pearson.columns)
pearson_cols

# %%
# Split dataset into training set and test set
from sklearn.model_selection import train_test_split # Import train_test_split function
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
from sklearn import metrics, tree
from sklearn.tree import export_graphviz, DecisionTreeClassifier # Import Decision Tree Classifier
dtree = tree.DecisionTreeClassifier(criterion = "gini", splitter = 'random', max_leaf_nodes = 10, min_samples_leaf = 5, max_depth= 5)
dtree.fit(X_train,y_train)

# %%
DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
            max_features=None, max_leaf_nodes=10, min_samples_leaf=5,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=None, splitter='random')

# %%
x_train_pred  = dtree.predict(X_train)

# %%
print("Accuracy:",metrics.accuracy_score(y_train, x_train_pred))

# %%
import pydotplus
from IPython.display import Image
dot_data = tree.export_graphviz(dtree, out_file=None, 
                     feature_names=pearson_cols,  
                     class_names=['0','1'],  
                     filled=True, rounded=True,  
                     special_characters=True)  
# graph = graphviz.Source(dot_data)  
# graph

pydot_graph = pydotplus.graph_from_dot_data(dot_data)
pydot_graph.write_png('original_tree.png')
pydot_graph.set_size('"9,5!"')
pydot_graph.write_png('resized_tree.png')

Image(pydot_graph.create_png())

# %%
# Create a Logistic Regression Object, perform Logistic Regression
from sklearn.linear_model import LogisticRegression
logistic_reg = LogisticRegression()
logistic_reg.fit(X_train, y_train)

# %%
# Perform prediction using the test dataset
from sklearn.metrics import confusion_matrix
y_pred = logistic_reg.predict(X_test)

# Show the Confusion Matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
cnf_matrix

# %%
import seaborn as sns
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))

# %%
# Linear SVC
from sklearn.svm import SVC, LinearSVC
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)


kfold = KFold(n_splits=10, random_state=42)
linear_svc = LinearSVC(max_iter=1000)
results_linearsvc= cross_val_score(linear_svc, X, training_scores_encoded, cv=kfold, scoring='accuracy')
print('Estimate accuracy',results_linearsvc.mean())

# %%
from sklearn.ensemble import RandomForestClassifier

# Random Forest
kfold = KFold(n_splits=10, random_state=42)
random_forest = RandomForestClassifier(n_estimators=100)
results_randomforest = cross_val_score(random_forest , X, training_scores_encoded, cv=kfold,scoring='accuracy')
print('Estimate accuracy',results_randomforest.mean())

# %%
from sklearn.linear_model import Perceptron

# Perceptron
kfold = KFold(n_splits=10, random_state=42)
perceptron = Perceptron(max_iter=1000,tol=1e-3)
results_perceptron = cross_val_score(perceptron, X, training_scores_encoded, cv=kfold,scoring='accuracy')
print('Estimate accuracy',results_perceptron.mean())

# %%
import pandas
from sklearn import model_selection
from sklearn.ensemble import VotingClassifier

kfold = KFold(n_splits=10, random_state=42)

# create the sub models
estimators = []

estimators.append(('logistic', logistic_reg))
estimators.append(('decision_tree', dtree))
estimators.append(('perceptron', perceptron))
estimators.append(('svm', linear_svc))
estimators.append(('random_forest', random_forest))


# create the ensemble model
ensemble = VotingClassifier(estimators, weights=[1,2,1,1,2])
results = model_selection.cross_val_score(ensemble, X, y, cv=kfold)
print('ensemble accuracy: ', results.mean()) 
# print(results)

# %%
df_md_national.info()

# %%
sn.set(rc={'figure.figsize':(16,10)})

sn.countplot(df_md_national.Social_distancing_index)
plt.xlabel("value")
plt.ylabel("count of target")
plt.title("Distribution of Social Distancing Variable")
plt.show()

# %% [markdown]
# # FEATURE SELECTION

# %% [markdown]
# # ANALYSIS

# %% [markdown]
# # KNOWLEDGE EXTRACTION
